# %% [markdown]
# # Lab 5: Transfer learning.
#
# Thanks to their capability to learn generalizable descriptors directly from images, deep Convolutional Neural Networks (CNNs) seem the ideal solution to most pattern recognition problems. On the other hand, to learn the image representation, CNNs need huge sets of annotated samples that are unfeasible in many every-day scenarios. This is the case, for example, of Computer-Aided Diagnosis (CAD) systems for digital pathology, where additional challenges are
# posed by the high variability of the cancerous tissue characteristics.
# In this notebooks you are going to implement 4 different training paradigms leveraging CNNs:
#
#
# 1.   Training from scratch
# 2.   Features extractor followed by SVM
# 3.   Fine tuning

# %% [markdown]
# # Import and settings

# %%
import os
import cv2
import glob
import numpy as np
import seaborn as sns
import tensorflow as tf
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import RandomizedSearchCV

# %%
# !git clone https://github.com/frpnz/dataset-BIOSTEC2018.git
ROOTDIR_DATASET = "/content/dataset-BIOSTEC2018/crc_images"
IMAGE_SIZE = 32
NUM_CLASSES = 3
BATCH_SIZE = 32
# Out:
# Cloning into 'dataset-BIOSTEC2018'...
# remote: Enumerating objects: 13518, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 13518 (delta 1), reused 6 (delta 1), pack-reused 13512 (from 1)
# Receiving objects: 100% (13518/13518), 1.87 GiB | 39.78 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Updating files: 100% (13501/13501), done.

# %% [markdown]
# ## Utils

# %%
def seaborn_cm(cm, ax, tick_labels, fontsize=14, title=None, sum_actual="over_columns",
               xrotation=0, yrotation=0):
    """
    Function to plot a confusion matrix
    """
    from matplotlib import cm as plt_cmap
    group_counts = ["{:0.0f}".format(value) for value in cm.flatten()]
    if sum_actual == "over_columns":
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    elif sum_actual == "over_rows":
        cm = cm.astype('float') / cm.sum(axis=0)[:, np.newaxis]
    else:
        print("sum_actual must be over_columns or over_rows")
        exit()
    cm = np.nan_to_num(cm)
    mean_acc = np.mean(np.diag(cm)[cm.sum(axis=1) != 0])
    std_acc = np.std(np.diag(cm))
    group_percentages = ["{:0.0f}".format(value*100) for value in cm.flatten()]
    cm_labels = [f"{c}\n{p}%" for c, p in zip(group_counts, group_percentages)]
    cm_labels = np.asarray(cm_labels).reshape(len(tick_labels), len(tick_labels))
    sns.heatmap(cm,
                ax=ax,
                annot=cm_labels,
                fmt='',
                cbar=False,
                cmap=plt_cmap.Greys,
                linewidths=1, linecolor='black',
                annot_kws={"fontsize": fontsize},
                xticklabels=tick_labels,
                yticklabels=tick_labels)
    ax.set_yticklabels(ax.get_yticklabels(), size=fontsize, rotation=yrotation)
    ax.set_xticklabels(ax.get_xticklabels(), size=fontsize, rotation=xrotation)
    if title:
        title = f"{title}\nMean accuracy {mean_acc * 100:.1f} +- {std_acc * 100:.1f}"
    else:
        title = f"Mean accuracy {mean_acc * 100:.1f} +- {std_acc * 100:.1f}"
    ax.set_title(title)
    if sum_actual == "over_columns":
        ax.set_ylabel("Actual")
        ax.set_xlabel("Predicted")
    else:
        ax.set_ylabel("Predicted")
        ax.set_xlabel("Actual")
    ax.axis("off")

# %% [markdown]
# # Assignment #1: create two tensorflow dataset for train and test.
# Leverage the API [tf.keras.utils.image_dataset_from_directory](https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory).

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    ROOTDIR_DATASET + "/train",
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    ROOTDIR_DATASET + "/test",
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    shuffle = False
)
# Out:
# Found 9000 files belonging to 3 classes.
# Found 4500 files belonging to 3 classes.

# %%
j = 0
fig, ax = plt.subplots(4, 4, figsize=(7, 7))
ax = ax.ravel()
for batch in train_ds.take(1):
    images = batch[0]
    labels = batch[1]
    for image, label in zip(images, labels):
        if j >= 16:
            break
        image = image.numpy().astype(np.uint8)
        ax[j].imshow(image)
        ax[j].axis("off")
        j += 1

# %% [markdown]
# # Assignment #2: dataset preparation
# 1.   Normalize images in the range [0, 1]
# 2.   Prepare the input pipeline via tf.data.Dataset methods

# %%
def process_data(image, label):
    return tf.cast(image, tf.float32) / 255., label

train_ds = train_ds.map(process_data, num_parallel_calls=tf.data.AUTOTUNE)
train_ds = train_ds.cache()
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE)
# because we loaded data from directory it already shuffled and batched the data

test_ds = test_ds.map(process_data, num_parallel_calls=tf.data.AUTOTUNE)
test_ds = test_ds.cache()
test_ds = test_ds.prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# # Assignment #3: train a VGG16 from scratch for 50 epochs

# %% [markdown]
# ![immagine.png](data:image/png;base64,...)

# %%
vgg16 = tf.keras.applications.VGG16(
    include_top=True,
    weights=None,
    input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3),
    classes=NUM_CLASSES
)

# %%
vgg16.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)
history = vgg16.fit(
    train_ds,
    validation_data=test_ds,
    epochs=50
)
# Out:
# Epoch 1/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 65s 184ms/step - accuracy: 0.6799 - loss: 0.6355 - val_accuracy: 0.6884 - val_loss: 0.6177
# Epoch 2/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 56ms/step - accuracy: 0.8302 - loss: 0.4188 - val_accuracy: 0.7416 - val_loss: 0.5344
# Epoch 3/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 57ms/step - accuracy: 0.8466 - loss: 0.3769 - val_accuracy: 0.7296 - val_loss: 0.5075
# Epoch 4/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 57ms/step - accuracy: 0.8727 - loss: 0.3270 - val_accuracy: 0.7696 - val_loss: 0.6260
# Epoch 5/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.8916 - loss: 0.2862 - val_accuracy: 0.7004 - val_loss: 0.7501
# Epoch 6/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9212 - loss: 0.2171 - val_accuracy: 0.8480 - val_loss: 0.3848
# Epoch 7/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9372 - loss: 0.1707 - val_accuracy: 0.8904 - val_loss: 0.2732
# Epoch 8/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 57ms/step - accuracy: 0.9404 - loss: 0.1711 - val_accuracy: 0.8689 - val_loss: 0.4271
# Epoch 9/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 57ms/step - accuracy: 0.9549 - loss: 0.1330 - val_accuracy: 0.8838 - val_loss: 0.3039
# Epoch 10/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9614 - loss: 0.1154 - val_accuracy: 0.8969 - val_loss: 0.3006
# Epoch 11/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9694 - loss: 0.0856 - val_accuracy: 0.8918 - val_loss: 0.3344
# Epoch 12/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9696 - loss: 0.0918 - val_accuracy: 0.8849 - val_loss: 0.5334
# Epoch 13/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9538 - loss: 0.1488 - val_accuracy: 0.9107 - val_loss: 0.3839
# Epoch 14/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9771 - loss: 0.0695 - val_accuracy: 0.9236 - val_loss: 0.3127
# Epoch 15/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9808 - loss: 0.0577 - val_accuracy: 0.9182 - val_loss: 0.3728
# Epoch 16/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9804 - loss: 0.0614 - val_accuracy: 0.8104 - val_loss: 0.6965
# Epoch 17/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9821 - loss: 0.0524 - val_accuracy: 0.9182 - val_loss: 0.4909
# Epoch 18/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9789 - loss: 0.0685 - val_accuracy: 0.9249 - val_loss: 0.3328
# Epoch 19/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9866 - loss: 0.0400 - val_accuracy: 0.8729 - val_loss: 0.9534
# Epoch 20/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9760 - loss: 0.0756 - val_accuracy: 0.9249 - val_loss: 0.2413
# Epoch 21/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9877 - loss: 0.0385 - val_accuracy: 0.9218 - val_loss: 0.2897
# Epoch 22/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9903 - loss: 0.0290 - val_accuracy: 0.8978 - val_loss: 0.5796
# Epoch 23/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 17s 59ms/step - accuracy: 0.9861 - loss: 0.0485 - val_accuracy: 0.9182 - val_loss: 0.4833
# Epoch 24/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9948 - loss: 0.0177 - val_accuracy: 0.9064 - val_loss: 0.4581
# Epoch 25/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9824 - loss: 0.0569 - val_accuracy: 0.8064 - val_loss: 0.8643
# Epoch 26/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9883 - loss: 0.0369 - val_accuracy: 0.9164 - val_loss: 0.3349
# Epoch 27/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9923 - loss: 0.0260 - val_accuracy: 0.8909 - val_loss: 0.5583
# Epoch 28/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9923 - loss: 0.0265 - val_accuracy: 0.9447 - val_loss: 0.2757
# Epoch 29/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9952 - loss: 0.0154 - val_accuracy: 0.9296 - val_loss: 0.4462
# Epoch 30/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9918 - loss: 0.0260 - val_accuracy: 0.9338 - val_loss: 0.6627
# Epoch 31/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9929 - loss: 0.0246 - val_accuracy: 0.9351 - val_loss: 0.3841
# Epoch 32/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9949 - loss: 0.0180 - val_accuracy: 0.9158 - val_loss: 0.5043
# Epoch 33/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9912 - loss: 0.0370 - val_accuracy: 0.9073 - val_loss: 0.4957
# Epoch 34/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9949 - loss: 0.0186 - val_accuracy: 0.9289 - val_loss: 0.3844
# Epoch 35/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9952 - loss: 0.0165 - val_accuracy: 0.9189 - val_loss: 0.3773
# Epoch 36/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9951 - loss: 0.0148 - val_accuracy: 0.9318 - val_loss: 0.3941
# Epoch 37/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9977 - loss: 0.0078 - val_accuracy: 0.8987 - val_loss: 0.7201
# Epoch 38/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9937 - loss: 0.0189 - val_accuracy: 0.9069 - val_loss: 0.8118
# Epoch 39/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9933 - loss: 0.0203 - val_accuracy: 0.9036 - val_loss: 0.3626
# Epoch 40/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9947 - loss: 0.0200 - val_accuracy: 0.9018 - val_loss: 0.9191
# Epoch 41/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9878 - loss: 0.0426 - val_accuracy: 0.9440 - val_loss: 0.3220
# Epoch 42/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9948 - loss: 0.0174 - val_accuracy: 0.9222 - val_loss: 0.5085
# Epoch 43/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9938 - loss: 0.0228 - val_accuracy: 0.8576 - val_loss: 1.0963
# Epoch 44/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9987 - loss: 0.0042 - val_accuracy: 0.9144 - val_loss: 0.4688
# Epoch 45/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9917 - loss: 0.0326 - val_accuracy: 0.9249 - val_loss: 0.5356
# Epoch 46/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9992 - loss: 0.0028 - val_accuracy: 0.9362 - val_loss: 0.5873
# Epoch 47/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9973 - loss: 0.0114 - val_accuracy: 0.9440 - val_loss: 0.4489
# Epoch 48/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9934 - loss: 0.0207 - val_accuracy: 0.9091 - val_loss: 0.8328
# Epoch 49/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9996 - loss: 0.0013 - val_accuracy: 0.9202 - val_loss: 1.0836
# Epoch 50/50
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9911 - loss: 0.0363 - val_accuracy: 0.9060 - val_loss: 0.2541

# %% [markdown]
# ## Plot train loss and accuracy among epochs (see [History](tf.keras.callbacks.History) object)

# %%
plt.style.use("Solarize_Light2")
fig, ax = plt.subplots(2, 1)

# plot_1
ax[0].plot(history.history['loss'], label='Training Loss', color='blue')
if 'val_loss' in history.history:
    ax[0].plot(history.history['val_loss'], label='Validation Loss', color='orange', linestyle='--')

ax[0].set_title('Loss over Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_xlabel('Epoch')
ax[0].legend(loc='upper right')

# plot_2
ax[1].plot(history.history['accuracy'], label='Training Accuracy', color='blue')
if 'val_accuracy' in history.history:
    ax[1].plot(history.history['val_accuracy'], label='Validation Accuracy', color='orange', linestyle='--')

ax[1].set_title('Accuracy over Epochs')
ax[1].set_ylabel('Accuracy')
ax[1].set_xlabel('Epoch')
ax[1].legend(loc='lower right')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Assignment #4: extract features from VGG16 pre-trained on ImageNet and then train and test a downstream SVM.
#
# Pipeline:
# 1. Features extraction from the CNN
# 2. PCA
# 3. SVM training and test
#
# N.B. Do not shuffle train and test in order to extract labels in the correct order.

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
     ROOTDIR_DATASET + "/train",
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=False
)


test_ds = tf.keras.preprocessing.image_dataset_from_directory(
     ROOTDIR_DATASET + "/test",
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    shuffle = False
)
# Out:
# Found 9000 files belonging to 3 classes.
# Found 4500 files belonging to 3 classes.

# %%
def process_data(image, label):
    image = tf.cast(image, tf.float32)
    return tf.keras.applications.vgg16.preprocess_input(image), label

train_ds = train_ds.map(process_data, num_parallel_calls=tf.data.AUTOTUNE)
train_ds = train_ds.cache()
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE)

test_ds = test_ds.map(process_data, num_parallel_calls=tf.data.AUTOTUNE)
test_ds = test_ds.cache()
test_ds = test_ds.prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
vgg16 = tf.keras.applications.VGG16(
    include_top=False,
    weights='imagenet',
    input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3),
    classes=NUM_CLASSES
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
feature_extractor = tf.keras.Sequential([
    vgg16,
    tf.keras.layers.GlobalAveragePooling2D()
])

# %%
train_features = feature_extractor.predict(train_ds)
test_features = feature_extractor.predict(test_ds)
# Out:
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 27s 93ms/step
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 13s 93ms/step

# %%
# labels_train = np.concatenate([np.argmax(y, axis=1) for _, y in train_ds], axis=0)
# labels_test = np.concatenate([np.argmax(y, axis=1) for _, y in test_ds], axis=0)

train_labels = np.concatenate([y for x, y in train_ds], axis=0)
test_labels = np.concatenate([y for x, y in test_ds], axis=0)

# %%
pca = PCA(n_components=0.95, random_state=42)

# %%
train_features_pca = pca.fit_transform(train_features)
test_features_pca = pca.transform(test_features)

# %%
svm_classifier = SVC(
    kernel='rbf',
    C=1.0,
    random_state=42
    )
svm_classifier.fit(train_features_pca, train_labels)
# Out:
# SVC(random_state=42)

# %%
predictions = svm_classifier.predict(test_features_pca)

# %%
cm = confusion_matrix(test_labels, predictions)
my_class_labels = ['AC', 'AD','H']
fig, ax = plt.subplots(figsize=(7, 7))
seaborn_cm(
    cm=cm,
    ax=ax,
    tick_labels=my_class_labels,
    fontsize=14,
    title="SVM Confusion Matrix"
)
plt.show()


from sklearn.metrics import classification_report, accuracy_score
accuracy = accuracy_score(test_labels, predictions)
print(f"\nSVM Test Accuracy: {accuracy * 100:.2f}%")
print("\nClassification Report:")
print(classification_report(test_labels, predictions))
# Out:
# SVM Test Accuracy: 87.93%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84      1500
#            1       0.91      0.92      0.92      1500
#            2       0.88      0.89      0.88      1500
#
#     accuracy                           0.88      4500
#    macro avg       0.88      0.88      0.88      4500
# weighted avg       0.88      0.88      0.88      4500

# %% [markdown]
# # Assignment #5: Fine tune the VGG16 pre-trained on ImageNet.

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    ROOTDIR_DATASET + "/train",
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
     ROOTDIR_DATASET + "/test",
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    shuffle = False
)
# Out:
# Found 9000 files belonging to 3 classes.
# Found 4500 files belonging to 3 classes.

# %%
def process_data(image, label):
    image = tf.cast(image, tf.float32)
    return  tf.keras.applications.vgg16.preprocess_input(image), label

train_ds = train_ds.map(process_data, num_parallel_calls=tf.data.AUTOTUNE)
train_ds = train_ds.cache()
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE)

test_ds = test_ds.map(process_data, num_parallel_calls=tf.data.AUTOTUNE)
test_ds = test_ds.cache()
test_ds = test_ds.prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
base_model = tf.keras.applications.VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3),
    classes=NUM_CLASSES
)

base_model.trainable = False # Freeze the entire base model

inputs = tf.keras.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
x = base_model(inputs, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
outputs = tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')(x)
model = tf.keras.Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)
history = model.fit(
    train_ds,
    epochs=20,
    validation_data=test_ds
)
# Out:
# Epoch 1/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 41s 136ms/step - accuracy: 0.7523 - loss: 2.1538 - val_accuracy: 0.8296 - val_loss: 1.0147
# Epoch 2/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8603 - loss: 0.7590 - val_accuracy: 0.8349 - val_loss: 0.8471
# Epoch 3/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8806 - loss: 0.5354 - val_accuracy: 0.8409 - val_loss: 0.7163
# Epoch 4/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8932 - loss: 0.4138 - val_accuracy: 0.8567 - val_loss: 0.5954
# Epoch 5/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9008 - loss: 0.3486 - val_accuracy: 0.8647 - val_loss: 0.5422
# Epoch 6/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9069 - loss: 0.3129 - val_accuracy: 0.8698 - val_loss: 0.5145
# Epoch 7/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9122 - loss: 0.2924 - val_accuracy: 0.8707 - val_loss: 0.5193
# Epoch 8/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9113 - loss: 0.2785 - val_accuracy: 0.8673 - val_loss: 0.5291
# Epoch 9/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9147 - loss: 0.2691 - val_accuracy: 0.8687 - val_loss: 0.5365
# Epoch 10/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9159 - loss: 0.2624 - val_accuracy: 0.8693 - val_loss: 0.5414
# Epoch 11/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9174 - loss: 0.2563 - val_accuracy: 0.8704 - val_loss: 0.5466
# Epoch 12/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9183 - loss: 0.2515 - val_accuracy: 0.8702 - val_loss: 0.5515
# Epoch 13/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9192 - loss: 0.2481 - val_accuracy: 0.8720 - val_loss: 0.5575
# Epoch 14/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9203 - loss: 0.2454 - val_accuracy: 0.8722 - val_loss: 0.5641
# Epoch 15/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9211 - loss: 0.2428 - val_accuracy: 0.8716 - val_loss: 0.5694
# Epoch 16/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9216 - loss: 0.2404 - val_accuracy: 0.8724 - val_loss: 0.5734
# Epoch 17/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9228 - loss: 0.2379 - val_accuracy: 0.8733 - val_loss: 0.5773
# Epoch 18/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9241 - loss: 0.2357 - val_accuracy: 0.8733 - val_loss: 0.5805
# Epoch 19/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9244 - loss: 0.2338 - val_accuracy: 0.8733 - val_loss: 0.5836
# Epoch 20/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9250 - loss: 0.2320 - val_accuracy: 0.8731 - val_loss: 0.5877

# %%
plt.style.use("Solarize_Light2")
fig, ax = plt.subplots(2, 1)

# plot_1
ax[0].plot(history.history['loss'], label='Training Loss', color='blue')
if 'val_loss' in history.history:
    ax[0].plot(history.history['val_loss'], label='Validation Loss', color='orange', linestyle='--')

ax[0].set_title('Loss over Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_xlabel('Epoch')
ax[0].legend(loc='upper right')

# plot_2
ax[1].plot(history.history['accuracy'], label='Training Accuracy', color='blue')
if 'val_accuracy' in history.history:
    ax[1].plot(history.history['val_accuracy'], label='Validation Accuracy', color='orange', linestyle='--')

ax[1].set_title('Accuracy over Epochs')
ax[1].set_ylabel('Accuracy')
ax[1].set_xlabel('Epoch')
ax[1].legend(loc='lower right')

plt.tight_layout()
plt.show()

# %%
prediction_probs = model.predict(test_ds)

predicted_labels = np.argmax(prediction_probs, axis=1)

true_labels = np.concatenate([y for x, y in test_ds], axis=0)

class_names = ['AC', 'AD', 'H']

accuracy = accuracy_score(true_labels, predicted_labels)
print(f"Accuracy: {accuracy * 100:.2f}%\n")

print("Classification Report:")
print(classification_report(true_labels, predicted_labels, target_names=class_names))


cm = confusion_matrix(true_labels, predicted_labels)

fig, ax = plt.subplots(figsize=(8, 8))

seaborn_cm(
    cm=cm,
    ax=ax,
    tick_labels=class_names,
    fontsize=14,
    title="Confusion Matrix"
)

plt.tight_layout()
plt.show()
# Out:
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
# Accuracy: 87.31%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           AC       0.80      0.88      0.84      1500
#           AD       0.91      0.88      0.90      1500
#            H       0.91      0.86      0.89      1500
#
#     accuracy                           0.87      4500
#    macro avg       0.88      0.87      0.87      4500
# weighted avg       0.88      0.87      0.87      4500

# %%
base_model = tf.keras.applications.VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3),
    classes=NUM_CLASSES
)

base_model.trainable = True # Unfreeze the base model

inputs = tf.keras.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
x = base_model(inputs, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
outputs = tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')(x)
model = tf.keras.Model(inputs, outputs)

for layer in base_model.layers[:15]:
    layer.trainable = False

for i, layer in enumerate(base_model.layers):
    print(f"Layer {i} | {layer.name} | Trainable: {layer.trainable}")

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

history_finetune = model.fit(
    train_ds,
    epochs=22,
    validation_data=test_ds
)
# Out:
# Layer 0 | input_layer_21 | Trainable: False
# Layer 1 | block1_conv1 | Trainable: False
# Layer 2 | block1_conv2 | Trainable: False
# Layer 3 | block1_pool | Trainable: False
# Layer 4 | block2_conv1 | Trainable: False
# Layer 5 | block2_conv2 | Trainable: False
# Layer 6 | block2_pool | Trainable: False
# Layer 7 | block3_conv1 | Trainable: False
# Layer 8 | block3_conv2 | Trainable: False
# Layer 9 | block3_conv3 | Trainable: False
# Layer 10 | block3_pool | Trainable: False
# Layer 11 | block4_conv1 | Trainable: False
# Layer 12 | block4_conv2 | Trainable: False
# Layer 13 | block4_conv3 | Trainable: False
# Layer 14 | block4_pool | Trainable: False
# Layer 15 | block5_conv1 | Trainable: True
# Layer 16 | block5_conv2 | Trainable: True
# Layer 17 | block5_conv3 | Trainable: True
# Layer 18 | block5_pool | Trainable: True
# Epoch 1/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.8371 - loss: 1.2176 - val_accuracy: 0.8469 - val_loss: 0.6904
# Epoch 2/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9246 - loss: 0.3096 - val_accuracy: 0.8513 - val_loss: 0.6135
# Epoch 3/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9529 - loss: 0.1619 - val_accuracy: 0.8471 - val_loss: 0.6551
# Epoch 4/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9698 - loss: 0.0923 - val_accuracy: 0.8540 - val_loss: 0.6093
# Epoch 5/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9808 - loss: 0.0602 - val_accuracy: 0.8713 - val_loss: 0.5538
# Epoch 6/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9881 - loss: 0.0424 - val_accuracy: 0.8869 - val_loss: 0.4844
# Epoch 7/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9894 - loss: 0.0357 - val_accuracy: 0.8927 - val_loss: 0.4917
# Epoch 8/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9868 - loss: 0.0370 - val_accuracy: 0.8887 - val_loss: 0.5507
# Epoch 9/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9903 - loss: 0.0288 - val_accuracy: 0.9024 - val_loss: 0.4949
# Epoch 10/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9903 - loss: 0.0282 - val_accuracy: 0.9042 - val_loss: 0.4930
# Epoch 11/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9882 - loss: 0.0296 - val_accuracy: 0.8933 - val_loss: 0.6463
# Epoch 12/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9873 - loss: 0.0344 - val_accuracy: 0.8800 - val_loss: 0.7111
# Epoch 13/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9882 - loss: 0.0346 - val_accuracy: 0.8916 - val_loss: 0.5818
# Epoch 14/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9930 - loss: 0.0215 - val_accuracy: 0.8793 - val_loss: 0.7705
# Epoch 15/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9927 - loss: 0.0241 - val_accuracy: 0.8978 - val_loss: 0.6131
# Epoch 16/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9979 - loss: 0.0066 - val_accuracy: 0.8969 - val_loss: 0.5859
# Epoch 17/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9983 - loss: 0.0051 - val_accuracy: 0.8949 - val_loss: 0.5784
# Epoch 18/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9996 - loss: 0.0029 - val_accuracy: 0.8993 - val_loss: 0.6142
# Epoch 19/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9999 - loss: 0.0019 - val_accuracy: 0.8971 - val_loss: 0.5991
# Epoch 20/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 0.9009 - val_loss: 0.5639
# Epoch 21/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 1.0000 - loss: 7.0270e-04 - val_accuracy: 0.9038 - val_loss: 0.5650
# Epoch 22/22
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 1.0000 - loss: 5.4387e-04 - val_accuracy: 0.9013 - val_loss: 0.5723

# %%
plt.style.use("Solarize_Light2")
fig, ax = plt.subplots(2, 1)

# plot_1
ax[0].plot(history_finetune.history['loss'], label='Training Loss', color='blue')
if 'val_loss' in history_finetune.history:
    ax[0].plot(history_finetune.history['val_loss'], label='Validation Loss', color='orange', linestyle='--')

ax[0].set_title('Loss over Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_xlabel('Epoch')
ax[0].legend(loc='upper right')

# plot_2
ax[1].plot(history_finetune.history['accuracy'], label='Training Accuracy', color='blue')
if 'val_accuracy' in history_finetune.history:
    ax[1].plot(history_finetune.history['val_accuracy'], label='Validation Accuracy', color='orange', linestyle='--')

ax[1].set_title('Accuracy over Epochs')
ax[1].set_ylabel('Accuracy')
ax[1].set_xlabel('Epoch')
ax[1].legend(loc='lower right')

plt.tight_layout()
plt.show()

# %%
prediction_probs = model.predict(test_ds)

predicted_labels = np.argmax(prediction_probs, axis=1)

true_labels = np.concatenate([y for x, y in test_ds], axis=0)

class_names = ['AC', 'AD', 'H']

accuracy = accuracy_score(true_labels, predicted_labels)
print(f"Accuracy: {accuracy * 100:.2f}%\n")

print("Classification Report:")
print(classification_report(true_labels, predicted_labels, target_names=class_names))


cm = confusion_matrix(true_labels, predicted_labels)

fig, ax = plt.subplots(figsize=(8, 8))

seaborn_cm(
    cm=cm,
    ax=ax,
    tick_labels=class_names,
    fontsize=14,
    title="Confusion Matrix"
)

plt.tight_layout()
plt.show()
# Out:
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
# Accuracy: 90.13%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           AC       0.90      0.86      0.88      1500
#           AD       0.90      0.96      0.93      1500
#            H       0.91      0.89      0.90      1500
#
#     accuracy                           0.90      4500
#    macro avg       0.90      0.90      0.90      4500
# weighted avg       0.90      0.90      0.90      4500
